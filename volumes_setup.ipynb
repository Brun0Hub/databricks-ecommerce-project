-- %%
USE CATALOG ecommerce_catalog

-- %%
SHOW SCHEMAS IN ecommerce_catalog LIKE '00_landing'

-- %% [markdown]
-- ###Creating the Schema 00_landing volumes

-- %%
CREATE VOLUME IF NOT EXISTS ecommerce_catalog.00_landing.raw_files;
